# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/stharshine/.local/lib/python3.10/site-packages (0.12.1)
# Requirement already satisfied: numpy>=1.17 in /home/stharshine/.local/lib/python3.10/site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: pandas>=0.25 in /home/stharshine/.local/lib/python3.10/site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/stharshine/.local/lib/python3.10/site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/stharshine/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/stharshine/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/stharshine/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/stharshine/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /home/stharshine/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/stharshine/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/stharshine/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /home/stharshine/.local/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
#Read csv
data_2014 = pd.read_csv("1-Data/OSMI 2014 Mental Health in Tech Survey Results - OSMI Mental Health in Tech Survey 2019.csv")
data_2014.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
#
#   mental_vs_physical obs_consequence comments
# 0                Yes              No      NaN
# 1         Don't know              No      NaN
# 2                 No              No      NaN
# 3                 No             Yes      NaN
# 4         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %%
#cleaning data

data_2014_clean=data_2014.iloc[:,[1,2,3,7,9,10,11,12,13,14,18]]

data_2014_clean
# Out:
#       Age  Gender         Country treatment    no_employees remote_work  \
# 0      37  Female   United States       Yes            6-25          No
# 1      44       M   United States        No  More than 1000          No
# 2      32    Male          Canada        No            6-25          No
# 3      31    Male  United Kingdom       Yes          26-100          No
# 4      31    Male   United States        No         100-500         Yes
# ...   ...     ...             ...       ...             ...         ...
# 1254   26    male  United Kingdom       Yes          26-100          No
# 1255   32    Male   United States       Yes          26-100         Yes
# 1256   34    male   United States       Yes  More than 1000          No
# 1257   46       f   United States        No         100-500         Yes
# 1258   25    Male   United States       Yes          26-100          No
#
#      tech_company    benefits care_options wellness_program  \
# 0             Yes         Yes     Not sure               No
# 1              No  Don't know           No       Don't know
# 2             Yes          No           No               No
# 3             Yes          No          Yes               No
# 4             Yes         Yes           No       Don't know
# ...           ...         ...          ...              ...
# 1254          Yes          No           No               No
# 1255          Yes         Yes          Yes               No
# 1256          Yes         Yes          Yes               No
# 1257          Yes          No          Yes               No
# 1258           No         Yes          Yes               No
#
#      mental_health_consequence
# 0                           No
# 1                        Maybe
# 2                           No
# 3                          Yes
# 4                           No
# ...                        ...
# 1254                        No
# 1255                        No
# 1256                       Yes
# 1257                       Yes
# 1258                     Maybe
#
# [1259 rows x 11 columns]

# %%
company_df = data_2014_clean.groupby('tech_company') #i made sure to have only tech companies
tech_company_df = company_df.get_group('Yes')
#mental_health_df = tech_company_df[['Country', 'care_options']].value_counts()

# %%
mental_health_df1=tech_company_df[tech_company_df["care_options"]=="Yes"]

# %%
mental_health_df2=mental_health_df1.groupby('Country').count() #it counts how many comapanies per country
care_per_company=mental_health_df2["care_options"] #dataframe for care options in each comapny per country

care_per_company.plot.bar()
plt.xlabel("Country")
plt.ylabel("Care Options in Tech Companies")
plt.title("Number of Care Options in Tech Companies per Country")
# Out:
# Text(0.5, 1.0, 'Number of Care Options in Tech Companies per Country')
